# %% [markdown]
# # **Comparacion inicial de 30 modelos en su forma básica**

# %% [markdown]
# ## **Importación de librerías necesarias**

# %%
# Importando librerías
import pandas as pd
import lazypredict
from lazypredict.Supervised import LazyClassifier
from sklearn.metrics import matthews_corrcoef

# %% [markdown]
# ## **Entrenamiento y predicción de los modelos**

# %%
# Definición y construcción de LazyClassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=matthews_corrcoef)

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
X_train = train.drop('class', axis=1)
y_train = train['class'].copy()
X_test = test.drop('class', axis=1)
y_test = test['class'].copy()
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
# Out:
#  97%|█████████▋| 28/29 [07:07<00:09,  9.35s/it]
# [LightGBM] [Info] Number of positive: 6941, number of negative: 7661
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.027029 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 23939
# [LightGBM] [Info] Number of data points in the train set: 14602, number of used features: 113
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.475346 -> initscore=-0.098697
# [LightGBM] [Info] Start training from score -0.098697
# 100%|██████████| 29/29 [07:28<00:00, 15.47s/it]

# %%
models
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.90               0.90     0.90      0.90
# RandomForestClassifier             0.89               0.89     0.89      0.89
# XGBClassifier                      0.89               0.89     0.89      0.89
# LGBMClassifier                     0.89               0.89     0.89      0.89
# SVC                                0.88               0.88     0.88      0.88
# KNeighborsClassifier               0.88               0.87     0.87      0.88
# BaggingClassifier                  0.86               0.86     0.86      0.86
# NuSVC                              0.85               0.85     0.85      0.85
# LabelPropagation                   0.83               0.83     0.83      0.83
# LabelSpreading                     0.83               0.83     0.83      0.83
# LogisticRegression                 0.82               0.82     0.82      0.82
# LinearDiscriminantAnalysis         0.82               0.82     0.82      0.82
# LinearSVC                          0.82               0.82     0.82      0.82
# RidgeClassifierCV                  0.82               0.82     0.82      0.82
# AdaBoostClassifier                 0.82               0.82     0.82      0.82
# CalibratedClassifierCV             0.82               0.82     0.82      0.82
# RidgeClassifier                    0.82               0.82     0.82      0.82
# DecisionTreeClassifier             0.81               0.81     0.81      0.81
# SGDClassifier                      0.81               0.81     0.81      0.81
# ExtraTreeClassifier                0.79               0.79     0.79      0.79
# GaussianNB                         0.74               0.74     0.74      0.74
# Perceptron                         0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.73     0.73      0.73
# BernoulliNB                        0.73               0.73     0.73      0.73
# PassiveAggressiveClassifier        0.73               0.73     0.73      0.73
# QuadraticDiscriminantAnalysis      0.64               0.65     0.65      0.61
# DummyClassifier                    0.52               0.50     0.50      0.35
#
#                                matthews_corrcoef  Time Taken
# Model
# ExtraTreesClassifier                        0.80        7.50
# RandomForestClassifier                      0.79       18.70
# XGBClassifier                               0.78       12.94
# LGBMClassifier                              0.78       21.26
# SVC                                         0.77       28.07
# KNeighborsClassifier                        0.75        3.30
# BaggingClassifier                           0.73       20.40
# NuSVC                                       0.71       55.21
# LabelPropagation                            0.69       47.60
# LabelSpreading                              0.69       59.33
# LogisticRegression                          0.64        1.13
# LinearDiscriminantAnalysis                  0.64       72.82
# LinearSVC                                   0.64       10.59
# RidgeClassifierCV                           0.64        0.49
# AdaBoostClassifier                          0.64       11.75
# CalibratedClassifierCV                      0.64       52.16
# RidgeClassifier                             0.64        0.62
# DecisionTreeClassifier                      0.62        2.64
# SGDClassifier                               0.62        1.08
# ExtraTreeClassifier                         0.58        0.25
# GaussianNB                                  0.49        0.28
# Perceptron                                  0.48        0.26
# NearestCentroid                             0.47        0.21
# BernoulliNB                                 0.46       12.30
# PassiveAggressiveClassifier                 0.45        0.44
# QuadraticDiscriminantAnalysis               0.34        0.39
# DummyClassifier                             0.00        0.15

# %%
predictions
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# ExtraTreesClassifier               0.90               0.90     0.90      0.90
# RandomForestClassifier             0.89               0.89     0.89      0.89
# XGBClassifier                      0.89               0.89     0.89      0.89
# LGBMClassifier                     0.89               0.89     0.89      0.89
# SVC                                0.88               0.88     0.88      0.88
# KNeighborsClassifier               0.88               0.87     0.87      0.88
# BaggingClassifier                  0.86               0.86     0.86      0.86
# NuSVC                              0.85               0.85     0.85      0.85
# LabelPropagation                   0.83               0.83     0.83      0.83
# LabelSpreading                     0.83               0.83     0.83      0.83
# LogisticRegression                 0.82               0.82     0.82      0.82
# LinearDiscriminantAnalysis         0.82               0.82     0.82      0.82
# LinearSVC                          0.82               0.82     0.82      0.82
# RidgeClassifierCV                  0.82               0.82     0.82      0.82
# AdaBoostClassifier                 0.82               0.82     0.82      0.82
# CalibratedClassifierCV             0.82               0.82     0.82      0.82
# RidgeClassifier                    0.82               0.82     0.82      0.82
# DecisionTreeClassifier             0.81               0.81     0.81      0.81
# SGDClassifier                      0.81               0.81     0.81      0.81
# ExtraTreeClassifier                0.79               0.79     0.79      0.79
# GaussianNB                         0.74               0.74     0.74      0.74
# Perceptron                         0.74               0.74     0.74      0.74
# NearestCentroid                    0.74               0.73     0.73      0.73
# BernoulliNB                        0.73               0.73     0.73      0.73
# PassiveAggressiveClassifier        0.73               0.73     0.73      0.73
# QuadraticDiscriminantAnalysis      0.64               0.65     0.65      0.61
# DummyClassifier                    0.52               0.50     0.50      0.35
#
#                                matthews_corrcoef  Time Taken
# Model
# ExtraTreesClassifier                        0.80        7.50
# RandomForestClassifier                      0.79       18.70
# XGBClassifier                               0.78       12.94
# LGBMClassifier                              0.78       21.26
# SVC                                         0.77       28.07
# KNeighborsClassifier                        0.75        3.30
# BaggingClassifier                           0.73       20.40
# NuSVC                                       0.71       55.21
# LabelPropagation                            0.69       47.60
# LabelSpreading                              0.69       59.33
# LogisticRegression                          0.64        1.13
# LinearDiscriminantAnalysis                  0.64       72.82
# LinearSVC                                   0.64       10.59
# RidgeClassifierCV                           0.64        0.49
# AdaBoostClassifier                          0.64       11.75
# CalibratedClassifierCV                      0.64       52.16
# RidgeClassifier                             0.64        0.62
# DecisionTreeClassifier                      0.62        2.64
# SGDClassifier                               0.62        1.08
# ExtraTreeClassifier                         0.58        0.25
# GaussianNB                                  0.49        0.28
# Perceptron                                  0.48        0.26
# NearestCentroid                             0.47        0.21
# BernoulliNB                                 0.46       12.30
# PassiveAggressiveClassifier                 0.45        0.44
# QuadraticDiscriminantAnalysis               0.34        0.39
# DummyClassifier                             0.00        0.15

# %% [markdown]
# # **Métricas de los modelos**

# %%
# Plot de la precision
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models.index, x="Accuracy", data=models)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Plot del coeficiente de correlacion de Mathews
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=models.index, x="matthews_corrcoef", data=models)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]
